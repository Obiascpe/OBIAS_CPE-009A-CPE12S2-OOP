# %% [markdown]
# <a href="https://colab.research.google.com/github/Obiascpe/OBIAS_CPE-009A-CPE12S2-OOP/blob/main/Laboratory_Activity_2.1_Literals_and_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# <center>
#
# **Technological Institute of the Philippines**<br>
# Computer Engineering Department<br>
# Quezon city Campus</center>
#
# ---
# <center><h4> Activity No. and Title: 2.1 (Literals and Variables) </h4></center>
#
# ---
# <center>
#
# | Course: CPE 009 | Program: BSCpE |
# |--- | --- |
# | **Course Title**: Object Oriented Programming | **Date Performed**: January 15, 2026 |
# | **Section**: CPE12S2 | **Date Submitted**: January , 2026 |
# | **Student Name**: Obias, Jave Joaquin C. | **Instructor's Name**: Engr. Maria Rizette Sayo |
# </center>

# %% [markdown]
# **Objective/s of the activity:**
#
# 1. Implement literals and variables in a python program.
#
# **Intended Learning Outcome:**
#
# 1. Write a simple program implementing literals and variables.
# 2. Use comments and identify keywords from identifiers created by users.
#
# **Discussion:**
#
# 1. Discuss the use of variables, constants and literals in a python program.
#
# **Materials and Equipment:**
#
# 1.   List item
# 2.   List item
#
# **Procedure:**
#
# 1. A teacher wants to calculate the final grade in a CpE course and want to write it in a python program. The following are the requirements:
#
#   I. PRELIM GRADE = 50% Prelim Exam + 50% Prelim Class Standing (CS)
#
#   II. PRELIM CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
#
#   III. MIDTERM GRADE = 1/3 of PRELIM GRADE + 2/3 of (50% Midterm Exam + 50% Midterm Class Standing (CS))
#
#   IV. MIDTERM CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
#
#   V. FINAL GRADE = 1/3 of MIDTERM GRADE + 2/3 of (50% Final Exam + 50% Final Class Standing (CS))
#
#   VI. FINAL CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
#
#   VII. HOAs, Quizzes and Assignments are inputted as average of all submissions and are out of 100%.
#
#   VIII. Major exams are inputted out of 100%.
#
#   IX. Show the codes that successfully run the program.
#
#   X. Provide comments or documentation strings for your program.

# %%
# Place all the output of the procedures here

# %% [markdown]
# **Supplementary Activity**:
#
# 1.   List item
# 2.   List item

# %%
# Place all the output of the supplementary activity here

# %% [markdown]
# **Questions**: (write your answers in blue font color and questions in black)
#
# 1.   List item
# 2.   List item

# %% [markdown]
# **Conclusion**:
# (conclusion must be based from the objective and answers whether you attained the objective/s or not and a brief explanation how you attained it)

# %%
print("Student #1")
stud1 = input("Enter your name: ")

#PRELIM
print()
PHOA = float(input("Enter Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))

PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
print("Prelim CS is: ", PCS)
PEX = float(input("Enter Prelim Exam grade: "))

PG = PEX*.5 + PCS*.5
print("Prelim Grade is: ", "%.2f" % PG)

#MIDTERM
print()
MHOA = float(input("Enter Hands-on Activity grade: "))
MQUIZ = float(input("Enter Midterm Quiz grade: "))
MAS = float(input("Enter Midterm Assignment grade: "))

MCS = MHOA*.5 + MQUIZ*.3 + MAS*.2
print("Midterm CS is: ", MCS)
MEX = float(input("Enter Midterm Exam grade: "))

MG = ((1/3)*PG) + ((2/3)*(MEX*.5 + MCS*.5))
print("Midterm Grade is: ", "%.2f" % MG)

#FINAL
print()
FHOA = float(input("Enter Hands-on Activity grade: "))
FQUIZ = float(input("Enter Final Quiz grade: "))
FAS = float(input("Enter Final Assignment grade: "))

FCS = FHOA*.5 + FQUIZ*.3 + FAS*.2
print("Final CS is: ", FCS)
FEX = float(input("Enter Final Exam grade: "))

FG = ((1/3)*MG) + ((2/3)*(FEX*.5 + FCS*.5))
print("Final Grade is: ", "%.2f" % FG)

print()
print()
print("Student #2")
stud2 = input("Enter your name: ")

#PRELIM
print()
PHOA = float(input("Enter Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))

PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
print("Prelim CS is: ", PCS)
PEX = float(input("Enter Prelim Exam grade: "))

PG = PEX*.5 + PCS*.5
print("Prelim Grade is: ", "%.2f" % PG)

#MIDTERM
print()
MHOA = float(input("Enter Hands-on Activity grade: "))
MQUIZ = float(input("Enter Midterm Quiz grade: "))
MAS = float(input("Enter Midterm Assignment grade: "))

MCS = MHOA*.5 + MQUIZ*.3 + MAS*.2
print("Midterm CS is: ", MCS)
MEX = float(input("Enter Midterm Exam grade: "))

MG = ((1/3)*PG) + ((2/3)*(MEX*.5 + MCS*.5))
print("Midterm Grade is: ", "%.2f" % MG)

#FINAL
print()
FHOA = float(input("Enter Hands-on Activity grade: "))
FQUIZ = float(input("Enter Final Quiz grade: "))
FAS = float(input("Enter Final Assignment grade: "))

FCS = FHOA*.5 + FQUIZ*.3 + FAS*.2
print("Final CS is: ", FCS)
FEX = float(input("Enter Final Exam grade: "))

FG = ((1/3)*MG) + ((2/3)*(FEX*.5 + FCS*.5))
print("Final Grade is: ", "%.2f" % FG)

print()
print()
print("Student #3")
stud3 = input("Enter your name: ")

#PRELIM
print()
PHOA = float(input("Enter Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))

PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
print("Prelim CS is: ", PCS)
PEX = float(input("Enter Prelim Exam grade: "))

PG = PEX*.5 + PCS*.5
print("Prelim Grade is: ", "%.2f" % PG)

#MIDTERM
print()
MHOA = float(input("Enter Hands-on Activity grade: "))
MQUIZ = float(input("Enter Midterm Quiz grade: "))
MAS = float(input("Enter Midterm Assignment grade: "))

MCS = MHOA*.5 + MQUIZ*.3 + MAS*.2
print("Midterm CS is: ", MCS)
MEX = float(input("Enter Midterm Exam grade: "))

MG = ((1/3)*PG) + ((2/3)*(MEX*.5 + MCS*.5))
print("Midterm Grade is: ", "%.2f" % MG)

#FINAL
print()
FHOA = float(input("Enter Hands-on Activity grade: "))
FQUIZ = float(input("Enter Final Quiz grade: "))
FAS = float(input("Enter Final Assignment grade: "))

FCS = FHOA*.5 + FQUIZ*.3 + FAS*.2
print("Final CS is: ", FCS)
FEX = float(input("Enter Final Exam grade: "))

FG = ((1/3)*MG) + ((2/3)*(FEX*.5 + FCS*.5))
If
print("Final Grade is: ", "%.2f" % FG)
# Out:
# Student #1
# Enter your name: jave
#
# Enter Hands-on Activity grade: 99
# Enter Prelim Quiz grade: 99
# Enter Prelim Assignment grade: 99
# Prelim CS is:  99.0
# Enter Prelim Exam grade: 99
# Prelim Grade is:  99.00
#
# Enter Hands-on Activity grade: 99
# Enter Midterm Quiz grade: 99
# Enter Midterm Assignment grade: 99
# Midterm CS is:  99.0
# Enter Midterm Exam grade: 99
# Midterm Grade is:  99.00
#
# Enter Hands-on Activity grade: 99
# Enter Final Quiz grade: 99
# Enter Final Assignment grade: 99
# Final CS is:  99.0
# Enter Final Exam grade: 99
# Final Grade is:  99.00
#
#
# Student #2
# Enter your name: 99
#
# Enter Hands-on Activity grade: 99
# Enter Prelim Quiz grade: 99
# Enter Prelim Assignment grade: 99
# Prelim CS is:  99.0
# Enter Prelim Exam grade: 99
# Prelim Grade is:  99.00
#
# Enter Hands-on Activity grade: 99
# Enter Midterm Quiz grade: 99
# Enter Midterm Assignment grade: 99
# Midterm CS is:  99.0
# Enter Midterm Exam grade: 99
# Midterm Grade is:  99.00
#
# Enter Hands-on Activity grade: 99
# Enter Final Quiz grade: 99
# Enter Final Assignment grade: 99
# Final CS is:  99.0
# Enter Final Exam grade: 99
# Final Grade is:  99.00
#
#
# Student #3
# Enter your name: 99
#
# Enter Hands-on Activity grade: 99
# Enter Prelim Quiz grade: 99
# Enter Prelim Assignment grade: 99
# Prelim CS is:  99.0
# Enter Prelim Exam grade: 99
# Prelim Grade is:  99.00
#
# Enter Hands-on Activity grade: 99
# Enter Midterm Quiz grade: 99
# Enter Midterm Assignment grade: 99
# Midterm CS is:  99.0
# Enter Midterm Exam grade: 99
# Midterm Grade is:  99.00
#
# Enter Hands-on Activity grade: 99
# Enter Final Quiz grade: 99
# Enter Final Assignment grade: 99
# Final CS is:  99.0
# Enter Final Exam grade: 99
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4267932376.py in <cell line: 0>()
#     127
#     128 FG = ((1/3)*MG) + ((2/3)*(FEX*.5 + FCS*.5))
# --> 129 If
#     130 print("Final Grade is: ", "%.2f" % FG)
#
# NameError: name 'If' is not defined
