# %% [markdown]
# <a href="https://colab.research.google.com/github/Obiascpe/OBIAS_CPE-009A-CPE12S2-OOP/blob/main/Laboratory_Activity_3_Sequence_and_Mapping_Types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Activity No. 3.1 - Sequence and Mapping Types

# %% [markdown]
# Name: Obias, Jave Joaquin C.
#
# Section: CPE12S2
#
# Date performed: February 26, 2026

# %% [markdown]
# ## Contents
#  - [Procedures](#procedures)
#  - [Supplementary Activity](#supplementary_activities)
#  - [Conclusion](#conclusion)

# %% [markdown]
# ## Instructions for Lab Activities
# ---
# Document all procedures and supplementary tasks performed in the activity.
#
# You may use these links for reference on markdown with Jupyter:
#
# https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Notebook%20Basics.html
#
# https://colab.research.google.com/notebooks/welcome.ipynb
#
# https://colab.research.google.com/notebooks/markdown_guide.ipynb
#
# Be creative in documenting how you did the procedures below using the markdown. Also provide your observations as often as necessary per step.
#
# Place your code per **In [ ]** corresponding to the specified procedure. An example is given below

# %% [markdown]
# ## <a id="procedures">Procedures</a>

# %% [markdown]
# ## **LISTS**

# %% [markdown]
# 1\. Create a variable **numberlist** and assign it the value of [5,4,2,1,3].

# %%
#1
numberlist = [5, 4, 2, 1, 3]
print(numberlist)
# Out:
# [5, 4, 2, 1, 3]

# %% [markdown]
# 2\. Print the following values below:
#
# a. len(numberlist)
#
# b. numberlist[0]
#
# c. numberlist[1]
#
# d. numberlist[2]
#
# e. numberlist[3]
#
# f. numberlist[4]
#
# g. numberlist[5]
#
# h. numberlist[-1]
#
# j. numberlist[-3]
#
# k. numberlist[-4]
#
# l. numberlist[-5]
#
# m. numberlist[-6]
#
# Reminder: Use the print() command. The values numberlist[5] and numberlist[-6] should return an error.

# %%
#2a
print(len(numberlist))
# Out:
# 5

# %%
#2b
print(numberlist[0])
# Out:
# 5

# %%
#2c
print(numberlist[1])
# Out:
# 4

# %%
#2d
print(numberlist[2])
# Out:
# 2

# %%
#2e
print(numberlist[3])
# Out:
# 1

# %%
#2f
print(numberlist[4])
# Out:
# 3

# %%
#2g
#The values numberlist[5] should return an error.
print(numberlist[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_510/2214987656.py in <cell line: 0>()
#       1 #2g
#       2 #The values numberlist[5] should return an error.
# ----> 3 print(numberlist[5])
#
# IndexError: list index out of range

# %%
#2h
print(numberlist[-1])
# Out:
# 3

# %%
#2i
print(numberlist[-2])
# Out:
# 1

# %%
#2j
print(numberlist[-3])
# Out:
# 2

# %%
#2k
print(numberlist[-4])
# Out:
# 4

# %%
#2l
print(numberlist[-5])
# Out:
# 5

# %%
#2m
#The values numberlist[-6] should return an error.
print(numberlist[-6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_510/1661784153.py in <cell line: 0>()
#       1 #2m
#       2 #The values numberlist[-6] should return an error.
# ----> 3 print(numberlist[-6])
#
# IndexError: list index out of range

# %% [markdown]
# 3\. Write your observation after printing all the values.

# %%
#3
print("OBSERVATION:")
print("The list contains 5 elements and starts counting from 0.")
print("This means the valid positive indices are 0 to 4, and the valid negative indices are -1 to -5.")
print("If you try to access index 5 or -6, it gives an IndexError because those positions do not exist in the list.")
# Out:
# OBSERVATION:
# The list contains 5 elements and starts counting from 0.
# This means the valid positive indices are 0 to 4, and the valid negative indices are -1 to -5.
# If you try to access index 5 or -6, it gives an IndexError because those positions do not exist in the list.

# %% [markdown]
# 4\. Create a variable named **itemlist** and assign it the value of [1,-2.0,[1,2,3],”Word”]

# %%
#4
itemlist = [1, -2.0, [1, 2, 3], "Word"]
print(itemlist)
# Out:
# [1, -2.0, [1, 2, 3], 'Word']

# %% [markdown]
# 5\. Print the following values below:
#
# a. len(itemlist)
#
# b. itemlist[0]
#
# c. itemlist[1]
#
# d. itemlist[2]
#
# e. itemlist[3]
#
# f. len(itemlist[2])
#
# g. itemlist[2][0]
#
# h. itemlist[2][1]
#
# i. itemlist[2][2]
#
# j. itemlist[-1]
#
# k. itemlist[-2]
#
# l. itemlist[-3]
#
# m. itemlist[-4]
#
# n. len(itemlist[-2])
#
# o. itemlist[-2][0]
#
# p. itemlist[-2][1]
#
# q. itemlist[-2][2]
#
# r. itemlist[-2][-3]
#
# s. itemlist[-2][-2]
#
# t. itemlist[-2][-1]

# %%
#5a
print(len(itemlist))
# Out:
# 4

# %%
#5b
print(itemlist[0])
# Out:
# 1

# %%
#5c
print(itemlist[1])
# Out:
# -2.0

# %%
#5d
print(itemlist[2])
# Out:
# [1, 2, 3]

# %%
#5e
print(itemlist[3])
# Out:
# Word

# %%
#5f
print(len(itemlist[2]))
# Out:
# 3

# %%
#5g
print(itemlist[2][0])
# Out:
# 1

# %%
#5h
print(itemlist[2][1])
# Out:
# 2

# %%
#5i
print(itemlist[2][2])
# Out:
# 3

# %%
#5j
print(itemlist[-1])
# Out:
# Word

# %%
#5k
print(itemlist[-2])
# Out:
# [1, 2, 3]

# %%
#5l
print(itemlist[-3])
# Out:
# -2.0

# %%
#5m
print(itemlist[-4])
# Out:
# 1

# %%
#5n
print(len(itemlist[-2]))
# Out:
# 3

# %%
#5o
print(itemlist[-2][0])
# Out:
# 1

# %%
#5p
print(itemlist[-2][1])
# Out:
# 2

# %%
#5q
print(itemlist[-2][2])
# Out:
# 3

# %%
#5r
print(itemlist[-2][-3])
# Out:
# 1

# %%
#5s
print(itemlist[-2][-2])
# Out:
# 2

# %%
#5t
print(itemlist[-2][-1])
# Out:
# 3

# %% [markdown]
# 6\. Write your observation after printing all the values. What does len() do?

# %%
#6
print("OBSERVATION:")
print("The list itemlist has four elements, and one of them is another list inside it.")
print("The len() function tells how many elements are in the list, not the total of the numbers.")
print("Using positive or negative indexing helps access specific elements, including the values inside the nested list.")
# Out:
# OBSERVATION:
# The list itemlist has four elements, and one of them is another list inside it.
# The len() function tells how many elements are in the list, not the total of the numbers.
# Using positive or negative indexing helps access specific elements, including the values inside the nested list.

# %% [markdown]
# ## **Index Slicing**

# %% [markdown]
# 1\. Create a new variable **longlist** and assign it the value of numberlist + itemlist.

# %%
#1
longlist = numberlist + itemlist
print(longlist)
# Out:
# [5, 4, 2, 1, 3, 1, -2.0, [1, 2, 3], 'Word']

# %% [markdown]
# 2\. Print the following values below and write your observation for each of the following sub-groups (sub-headings):
#
# a. len(longlist)
#
# b. longlist [:]
#
# c. longlist[:9]
#
# d. longlist[0:]
#
# e. longlist[1:]
#
# f. longlist[2:]

# %%
#2a
print(len(longlist))
# Out:
# 9

# %%
#2b
print(longlist[:])
# Out:
# [5, 4, 2, 1, 3, 1, -2.0, [1, 2, 3], 'Word']

# %%
#2c
print(longlist[:9])
# Out:
# [5, 4, 2, 1, 3, 1, -2.0, [1, 2, 3], 'Word']

# %%
#2d
print(longlist[0:])
# Out:
# [5, 4, 2, 1, 3, 1, -2.0, [1, 2, 3], 'Word']

# %%
#2e
print(longlist[1:])
# Out:
# [4, 2, 1, 3, 1, -2.0, [1, 2, 3], 'Word']

# %%
#2f
print(longlist[2:])
# Out:
# [2, 1, 3, 1, -2.0, [1, 2, 3], 'Word']

# %% [markdown]
# ### **Index Slicing with Range**

# %% [markdown]
# g. longlist[2:5]
#
# h. longlist[5:2]
#
# i. longlist[8:]
#
# j. longlist[9:]

# %%
#2g
print(longlist[2:5])
# Out:
# [2, 1, 3]

# %%
#2h
print(longlist[5:2])
# Out:
# []

# %%
#2i
print(longlist[8:])
# Out:
# ['Word']

# %%
#2j
print(longlist[9:])
# Out:
# []

# %% [markdown]
# ### **Index Slicing using Negative Indices**

# %% [markdown]
# k. longlist[-9:]
#
# l. longlist[-8:]
#
# m. longlist[-8:-7]
#
# n. longlist[-1:]

# %%
#2k
print(longlist[-9:])
# Out:
# [5, 4, 2, 1, 3, 1, -2.0, [1, 2, 3], 'Word']

# %%
#2l
print(longlist[-8:])
# Out:
# [4, 2, 1, 3, 1, -2.0, [1, 2, 3], 'Word']

# %%
#2m
print(longlist[-8:-7])
# Out:
# [4]

# %%
#2n
print(longlist[-1:])
# Out:
# ['Word']

# %% [markdown]
# ### **Other properties of Index Slicing**

# %% [markdown]
# o. longlist[10:20]
#
# p. longlist[-7:5]

# %%
#2o
print(longlist[10:20])
# Out:
# []

# %%
#2p
print(longlist[-7:5])
# Out:
# [2, 1, 3]

# %% [markdown]
# ### **Index Slicing with Step parameter**

# %% [markdown]
# q. longlist[::1]
#
# r. longlist[::2]
#
# s. longlist[1:8:2]
#
# t. longlist[9:1:-1]
#
# u. longlist[-1::1]
#
# v. longlist[-1::-1]

# %%
#2q
print(longlist[::1])
# Out:
# [5, 4, 2, 1, 3, 1, -2.0, [1, 2, 3], 'Word']

# %%
#2r
print(longlist[::2])
# Out:
# [5, 2, 3, -2.0, 'Word']

# %%
#2s
print(longlist[1:8:2])
# Out:
# [4, 1, 1, [1, 2, 3]]

# %%
#2t
print(longlist[9:1:-1])
# Out:
# ['Word', [1, 2, 3], -2.0, 1, 3, 1, 2]

# %%
#2u
print(longlist[-1::21])
# Out:
# ['Word']

# %%
#2v
print(longlist[-1::-1])
# Out:
# ['Word', [1, 2, 3], -2.0, 1, 3, 1, 2, 4, 5]

# %% [markdown]
# 3\. Write your main observation about index slicing as a whole.

# %%
#3
print("OBSERVATION:")
print("Index slicing lets you take parts of a list by choosing where to start and stop, and it does not cause an error even if the numbers go beyond the list’s length.")
print("If the starting index is bigger than the ending index (without a negative step), it returns an empty list.")
print("Negative numbers count from the end of the list, and the step value controls how the list moves, including reversing it when using a negative step.")
# Out:
# OBSERVATION:
# Index slicing lets you take parts of a list by choosing where to start and stop, and it does not cause an error even if the numbers go beyond the list’s length.
# If the starting index is bigger than the ending index (without a negative step), it returns an empty list.
# Negative numbers count from the end of the list, and the step value controls how the list moves, including reversing it when using a negative step.

# %% [markdown]
# ## **List Methods and the Mutable Property of Lists**

# %% [markdown]
# 1\. Create a new variable **numberlist2** and assign it to be equal to **numberlist**.

# %%
#1
numberlist2 = numberlist
print(numberlist2)
# Out:
# [5, 4, 2, 1, 3]

# %% [markdown]
# 2\. Print the value of **numberlist**.

# %%
#2
print(numberlist)
# Out:
# [5, 4, 2, 1, 3]

# %% [markdown]
# 3\. Print the value of **numberlist2**.

# %%
#3
print(numberlist2)
# Out:
# [5, 4, 2, 1, 3]

# %% [markdown]
# 4\. Assign the value of **numberlist[0]** to be equal to 6.

# %%
#4
numberlist[0] = 6
print(numberlist)
# Out:
# [6, 4, 2, 1, 3]

# %% [markdown]
# 5\. Print the value of **numberlist**.

# %%
#5
print(numberlist)
# Out:
# [6, 4, 2, 1, 3]

# %% [markdown]
# 6\. Print the value of **numberlist2**.

# %%
#6
print(numberlist2)
# Out:
# [6, 4, 2, 1, 3]

# %% [markdown]
# 7\. Observe how numberlist2 is affected by changes in numberlist due to the assignment.

# %%
#7
print("OBSERVATION:")
print("After assigning numberlist2 = numberlist, both variables refer to the same list.")
print("So when the first element of numberlist is changed to 6, the change also appears in numberlist2.")
print("This shows that assigning one list to another does not create a new copy — they both point to the same list in memory.")
# Out:
# OBSERVATION:
# After assigning numberlist2 = numberlist, both variables refer to the same list.
# So when the first element of numberlist is changed to 6, the change also appears in numberlist2.
# This shows that assigning one list to another does not create a new copy — they both point to the same list in memory.

# %% [markdown]
# 8\. Change the value of **numberlist2** and assign it the value of **numberlist.copy()**

# %%
#8
numberlist2 = numberlist.copy()
print(numberlist2)
# Out:
# [6, 4, 2, 1, 3]

# %% [markdown]
# 9\. Print the value of **numberlist2**.

# %%
#9
print(numberlist2)
# Out:
# [6, 4, 2, 1, 3]

# %% [markdown]
# 10\. Assign the value of **numberlist[0]** to be equal to 5.

# %%
#10
numberlist[0] = 5
print(numberlist)
# Out:
# [5, 4, 2, 1, 3]

# %% [markdown]
# 11\. Print the value of **numberlist**.

# %%
#11
print(numberlist)
# Out:
# [5, 4, 2, 1, 3]

# %% [markdown]
# 12\. Print the value of **numberlist2**.

# %%
#12
print(numberlist2)
# Out:
# [6, 4, 2, 1, 3]

# %% [markdown]
# 13\. Write your observation about the immutable property and the difference of assigning numberlist2 to be equal to numberlist and the numberlist.copy() method.

# %%
#13
print("OBSERVATION:")
print("When numberlist2 = numberlist.copy() is used, it creates a separate copy of the list. So when the value of numberlist[0] is changed back to 5, numberlist2 does not change.")
print("This is different from assigning numberlist2 = numberlist, where both variables refer to the same list and any change affects both.")
print("Using .copy() makes a new list in memory, so changes in one list do not affect the other.")
# Out:
# OBSERVATION:
# When numberlist2 = numberlist.copy() is used, it creates a separate copy of the list. So when the value of numberlist[0] is changed back to 5, numberlist2 does not change.
# This is different from assigning numberlist2 = numberlist, where both variables refer to the same list and any change affects both.
# Using .copy() makes a new list in memory, so changes in one list do not affect the other.

# %% [markdown]
# ## **Exploring some List Functions and Methods**

# %% [markdown]
# 1\. Print the value of numberlist

# %%
#1
print(numberlist)
# Out:
# [5, 4, 2, 1, 3]

# %% [markdown]
# 2\. Run the command **numberlist.append(6)**

# %%
#2
numberlist.append(6)
print(numberlist)
# Out:
# [5, 4, 2, 1, 3, 6]

# %% [markdown]
# 3\. Print the value of numberlist

# %%
#3
print(numberlist)
# Out:
# [5, 4, 2, 1, 3, 6]

# %% [markdown]
# 4\. Run the command **numberlist.pop()**

# %%
#4
numberlist.pop()
print(numberlist)

# %% [markdown]
# 5\. Print the value of numberlist

# %%
#5
print(numberlist)
# Out:
# [5, 4, 2, 1, 3, 6]

# %% [markdown]
# 6\. Run the command **numberlist.sort()**

# %%
#6
numberlist.sort()
print(numberlist)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# 7\. Print the value of numberlist

# %%
#7
print(numberlist)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# 8\. Run the command **itemlist.sort()**

# %%
#8
itemlist.sort()
print(itemlist)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_510/1295506869.py in <cell line: 0>()
#       1 #8
# ----> 2 itemlist.sort()
#       3 print(itemlist)
#
# TypeError: '<' not supported between instances of 'list' and 'float'

# %% [markdown]
# 9\. Print the values: min(**numberlist**) and max(**numberlist**)

# %%
#9
print(min(numberlist))
print(max(numberlist))
# Out:
# 1
# 6

# %% [markdown]
# 10\. Print the value of longlist.count(1)

# %%
#10
print(longlist.count(1))
# Out:
# 2

# %% [markdown]
# 11\. Print the value of longlist.count(1)

# %%
#11
print(longlist.count(1))
# Out:
# 2

# %% [markdown]
# 12\. Print the value of longlist[7].count(1)

# %%
#12
print(longlist[7].count(1))
# Out:
# 1

# %% [markdown]
# ## **The in operator**

# %% [markdown]
# 1\. Type the code as shown:
#
# print(3 in longlist)

# %%
#1
print(3 in longlist)
# Out:
# True

# %% [markdown]
# 2\. Type the code as shown:
#
# print(15 in longlist)

# %%
#2
print(15 in longlist)
# Out:
# False

# %% [markdown]
# 3\. Type the code as shown below:
#
# num = int(input(“Enter a number: ”))
#
# if num in longlist:
# print(“The number is in longlist”)
#
# else:
# print(“The number is not in longlist”)

# %%
#3
num = int(input("Enter a number: "))
if num in longlist:
    print("The number is in longlist")
else:
    print("The number is not in longlist")
# Out:
# Enter a number: 1
# The number is in longlist

# %% [markdown]
# 4\. Write your observations on the in operator.

# %%
#4
print("OBSERVATION:")
print("The in operator checks whether a value exists in a list.")
print("It returns True if the value is found and False if it is not.")
print("This works for both direct checks and in conditional statements to control the flow of the program.")
# Out:
# OBSERVATION:
# The in operator checks whether a value exists in a list.
# It returns True if the value is found and False if it is not.
# This works for both direct checks and in conditional statements to control the flow of the program.

# %% [markdown]
# ## **Using a list in an iterative statement**

# %% [markdown]
# 1\. Type the code as shown below:
#
# for item in longlist:
# print(item)

# %%
#1
for item in longlist:
    print(item)
# Out:
# 5
# 4
# 2
# 1
# 3
# 1
# -2.0
# [1, 2, 3]
# Word

# %% [markdown]
# 2\. Type the code as shown below:
#
# i=0
# while i<len(longlist): print(longlist[i]) i+=1

# %%
#2
i=0
while i<len(longlist):
    print(longlist[i])
    i+=1
# Out:
# 5
# 4
# 2
# 1
# 3
# 1
# -2.0
# [1, 2, 3]
# Word

# %% [markdown]
# ## **Strings**

# %% [markdown]
# 1\. Create a variable named **message** and assign it the value of “Hello World”

# %%
#1
message = "Hello World"
print(message)
# Out:
# Hello World

# %% [markdown]
# 2\. Print the value of **message**

# %%
#2
print(message)
# Out:
# Hello World

# %% [markdown]
# 3\. Print the value: len(**message**)

# %%
#3
print(len(message))
# Out:
# 11

# %% [markdown]
# 4\. Apply the concept of index values in the **List** section and individually display the characters “H”, “E”, “L”, “L”, “O”
# using the print() function.
#
# Note: Try using positive indexes, then after seeing the result. Repeat the step using negative indexes.

# %%
#4
print(message[0])
print(message[1])
print(message[2])
print(message[3])
# Out:
# H
# e
# l
# l

# %% [markdown]
# 5\. Apply the concept of index values in the **List** section and display the string “Hold” using the Concatenate (+) operator on individual characters.
#
# Ex. print(message[0]+ message[1]+ message[2]+ message[3]+ message[4])

# %%
#5
print(message[0]+ message[1]+ message[2]+ message[3]+ message[4])
# Out:
# Hello

# %% [markdown]
# 6\. Apply the concept of index slicing in the **Index Slicing** section and display the word “Hello” as a whole string.

# %%
#6
print(message[0:5])
# Out:
# Hello

# %% [markdown]
# 7\. Apply the concept of index slicing in the **Index Slicing** section and display the word “World” as a whole string.

# %%
#7
print(message[6:11])
# Out:
# World

# %% [markdown]
# ## **String Methods**

# %% [markdown]
# 1\. Type the command and print the value message.upper()
#
# Ex. print(message.upper())

# %%
#1
print(message.upper())
# Out:
# HELLO WORLD

# %% [markdown]
# 2\. Type the command and print the value	message.lower()

# %%
#2
print(message.lower())
# Out:
# hello world

# %% [markdown]
# 3\. Type the command and print the value	message.title()

# %%
#3
print(message.title())
# Out:
# Hello World

# %% [markdown]
# 4\. Print the value “Value 1 is {}, and value 2 is {}”.format(-1,True)

# %%
#4
print("Value 1 is {}, and value 2 is {}".format(-1,True))
# Out:
# Value 1 is -1, and value 2 is True

# %% [markdown]
# 5\. Print the value message.split(' ')

# %%
#5
print(message.split(' '))
# Out:
# ['Hello', 'World']

# %% [markdown]
# 6\. Print the value message.count(‘l’)

# %%
#6
print(message.count('l'))
# Out:
# 3

# %% [markdown]
# 7\. Print the value message.replace(‘World’,‘CPE009’)

# %%
#7
print(message.replace('World','CPE009'))
# Out:
# Hello CPE009

# %% [markdown]
# 8\. Assign the value message.replace(‘World’,‘CPE009’) to message

# %%
#8
message = message.replace('World','CPE009')
print(message)
# Out:
# Hello CPE009

# %% [markdown]
# 9\. Type the command: help(“”)
#
# Find the commands used in previous tasks.

# %%
#9
help("")
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %% [markdown]
# ## **The in operator for Strings**

# %% [markdown]
# 1\. Type the code as shown:
#
# print(‘W’ in message)

# %%
#1
print('W' in message)
# Out:
# False

# %% [markdown]
# 2\. Type the code as shown:
#
# print(‘old’ in message)

# %%
#2
print('old' in message)
# Out:
# False

# %% [markdown]
# 3\. Type the codes below:
#
# word = input(“Enter a word: ”)
#
# if word in “The big brown fox jump over the lazy dog”:
#
# print(“The word is in the text”)
#
# else:
# print(“The word is not in the text”)

# %%
#3
word = input("Enter a word: ")
# Out:
# Enter a word: word

# %% [markdown]
# ## **Using a String in an iterative statement**

# %% [markdown]
# 1\. Type the code as shown below:
#
# for character in message:
# print(character)

# %%
#1
for character in message:
    print(character)
# Out:
# H
# e
# l
# l
# o
#
# C
# P
# E
# 0
# 0
# 9

# %% [markdown]
# 2\. Type the code as shown below:
#
# i = 0
# while i<len(message):
#
# print(message[i]) i+=1

# %%
#2
i = 0
while i<len(message):
    print(message[i])
    i+=1
# Out:
# H
# e
# l
# l
# o
#
# C
# P
# E
# 0
# 0
# 9

# %% [markdown]
# ## **Tuples**

# %% [markdown]
# 1\. Create a variable named tuplelist and assign the value of (1,2,3,4,5)

# %%
#1
tuplelist = (1,2,3,4,5)
print(tuplelist)
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# 2\. Print the following values:
#
# a. numberlist[0]
#
# b. numberlist[1]
#
# c. numberlist[2]
#
# d. numberlist[3]
#
# e. numberlist[4]
#
# f. numberlist[5]

# %%
#2a
print(numberlist[0])
# Out:
# 1

# %%
#2b
print(numberlist[1])
# Out:
# 2

# %%
#2c
print(numberlist[2])
# Out:
# 3

# %%
#2d
print(numberlist[3])
# Out:
# 4

# %%
#2e
print(numberlist[4])
# Out:
# 5

# %%
#2f
print(numberlist[5])
# Out:
# 6

# %% [markdown]
# 3\. Print the output of tuplelist + (1,2,3)

# %%
#3
print(tuplelist + (1,2,3))
# Out:
# (1, 2, 3, 4, 5, 1, 2, 3)

# %% [markdown]
# 4\. Assign tuplelist[0] = 15

# %%
#4
tuplelist[0] = 15
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_510/255674280.py in <cell line: 0>()
#       1 #4
# ----> 2 tuplelist[0] = 15
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# 5\. Observe the output.

# %%
#5
print("OBSERVATION:")
print("Tuples are immutable, so they cannot be changed.")

# %% [markdown]
# 6\. Try string slicing through the elements of tuplelist as in numberlist and message.

# %%
#6
print(tuplelist[0:3])
print(message[0:5])
# Out:
# (1, 2, 3)
# Hello

# %% [markdown]
# 7\. Create a for loop that would print the numbers inside the tuple.

# %%
#7
for item in tuplelist:
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## **Dictionaries**

# %% [markdown]
# 1\. Create a dictionary named
# **contactinfo** = {‘id’:1, ’first_name’:’John’, ’last_name’:’Doe’, ’contact_number’:’09060611233’}

# %%
#1
contactinfo = {'id':1, 'first_name':'John', 'last_name':'Doe', 'contact_number':'09060611233'}

# %% [markdown]
# 2\. Print the following values:
#
# a. contactinfo[‘id’]
#
# b. contactinfo[‘first_name’]
#
# c. contactinfo[‘last_name’]
#
# d. contactinfo[‘contact_number’]
#
# e. contactinfo[‘age’]

# %%
#2a
print(contactinfo['id'])
# Out:
# 1

# %%
#2b
print(contactinfo['first_name'])
# Out:
# John

# %%
#2c
print(contactinfo['last_name'])
# Out:
# Doe

# %%
#2d
print(contactinfo['contact_number'])
# Out:
# 09060611233

# %%
#2e
print(contactinfo['age'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_510/316281850.py in <cell line: 0>()
#       1 #2e
# ----> 2 print(contactinfo['age'])
#
# KeyError: 'age'

# %% [markdown]
# 3\. Type the code:
#
# for k,v in contactinfo:
#
# print(k)

# %%
#3
for k,v in contactinfo:
    print(k)
# Out:
# i
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_510/3601111079.py in <cell line: 0>()
#       1 #3
# ----> 2 for k,v in contactinfo:
#       3     print(k)
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# 4\. Type the code:
#
# for k,v in contactinfo.items():
#
# print(k,v)

# %%
#4
for k,v in contactinfo.items():
    print(k,v)
# Out:
# id 1
# first_name John
# last_name Doe
# contact_number 09060611233

# %% [markdown]
# 5\. Assign the values:
#
# a. contactinfo[‘id’] = 2
#
# b. contactinfo[‘first_name’] = ‘Max’

# %%
#5a
contactinfo['id'] = 2

# %%
#5b
contactinfo['first_name'] = 'Max'

# %% [markdown]
# 6\. Print **contactinfo**

# %%
#6
print(contactinfo)
# Out:
# {'id': 2, 'first_name': 'Max', 'last_name': 'Doe', 'contact_number': '09060611233'}

# %% [markdown]
# ## <a id="supplementary_activities">Supplementary Activity</a>

# %% [markdown]
# ### **Distance Formula**

# %% [markdown]
# 1\. Make a program that would calculate the distance between two points given a list of coordinates. Use the distance formula.
#
# coorindates_list = [(1,1), (2,3)]

# %%
#Supplementary Act No.1

# List of coordinates
coordinates_list = [(1, 1), (2, 3)]

# Get the first point
x1 = coordinates_list[0][0]
y1 = coordinates_list[0][1]

# Get the second point
x2 = coordinates_list[1][0]
y2 = coordinates_list[1][1]

# Calculate the distance using the distance formula
distance = ((x2 - x1)**2 + (y2 - y1)**2)**0.5

# Print the result
print("The distance between the two points is:", distance)
# Out:
# The distance between the two points is: 2.23606797749979

# %% [markdown]
# ### **Simple Word Filter**

# %% [markdown]
# 2\. For a given string input, replace all the words “stupid” with an asterisk * equal to the length of the string. The new
# string value should be displayed with the asterisks.

# %%
#Supplementary Act No.2

# Ask the user to enter a sentence
text = input("Enter a sentence: ")

# Word to replace
bad_word = "stupid"

# Create a replacement made of asterisks
stars = "*" * len(bad_word)

# Replace all occurrences (case insensitive)
result = text.replace(bad_word, stars)
result = result.replace(bad_word.capitalize(), stars)
result = result.replace(bad_word.upper(), stars)

# Print the updated sentence
print("Updated sentence:")
print(result)
# Out:
# Enter a sentence: My name is Jave Joaquin C. Obias
# Updated sentence:
# My name is Jave Joaquin C. Obias

# %% [markdown]
# ### **Phonebook**

# %% [markdown]
# 3\. Create a simple phonebook program that can read from a list of dictionaries. The program should be able to display a
# person’s name, contact, and address based from a user input which is the id of the record.

# %%
#Supplementary Act No.3

# List of contacts (each contact is a dictionary)
phonebook = [
    {"id": 1, "name": "Alice", "contact": "123-456-7890", "address": "123 Main St"},
    {"id": 2, "name": "Bob", "contact": "987-654-3210", "address": "456 Elm St"},
    {"id": 3, "name": "Charlie", "contact": "555-555-5555", "address": "789 Oak St"}
]

# Ask the user to enter the ID of the contact
user_id = int(input("Enter the ID of the contact you want to find: "))

# Flag to check if ID exists
found = False

# Search for the contact by ID
for person in phonebook:
    if person["id"] == user_id:
        print("Name:", person["name"])
        print("Contact:", person["contact"])
        print("Address:", person["address"])
        found = True
        break

# If ID was not found
if not found:
    print("No contact found with that ID.")
# Out:
# Enter the ID of the contact you want to find: 2517052
# No contact found with that ID.

# %% [markdown]
# ## <a id="conclusion">Conclusion</a>

# %% [markdown]
# In this activity, I learned about different data types in Python such as lists, tuples, strings, and dictionaries and how each of them is used to store data in different ways. I understood that lists can be changed, while tuples cannot be modified once they are created, strings are used for text, and dictionaries store information using key and value pairs. I also practiced how to display elements using indexing and loops, which helps in accessing specific values from these data structures. In addition, I used some string methods to modify text, such as replacing words and changing letter cases. Overall, the activity helped me better understand how Python organizes and handles data while improving my basic programming skills.
