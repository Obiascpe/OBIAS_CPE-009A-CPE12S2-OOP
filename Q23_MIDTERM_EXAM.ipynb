# %% [markdown]
# <a href="https://colab.research.google.com/github/Obiascpe/OBIAS_CPE-009A-CPE12S2-OOP/blob/main/Q23_MIDTERM_EXAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Write a program that uses nested loops to print this pattern:
#
# *
#
# **
#
# ***
#
# ****
#
# *****
#
# ****
#
# ***
#
# **
#
# *

# %%
#Question 23
i = "*"
for x in range(1,6):
    print(i*x)
for y in range(4,0,-1):
    print(i*y)
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *
